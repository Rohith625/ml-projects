# %% [markdown]
# python basics

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# #datatypes

# %% [markdown]
# 1. Int
# 2.floating
# 3.strings

# %%
i=8
print(type(i))
# Out:
# <class 'int'>

# %%
n=2.88
print(type(n))
# Out:
# <class 'float'>

# %%
str="rohith"
print(type(str))
# Out:
# <class 'str'>

# %% [markdown]
# #constants and variables

# %%
superhero="Hanuman"
print(superhero)
# Out:
# Hanuman

# %%
m=5
m=10
print(m)
# Out:
# 10

# %%
m,n=56,79
print(m,n)
# Out:
# 56 79

# %% [markdown]
# #input function

# %%
i=int(input("enter the number : "))
n=int(input("enter another number : "))
m=i+n
print(m)
# Out:
# enter the number : 2
# enter another number : 3
# 5

# %%
for i in range(1,6):
  laptop_price=int(input(f"enter the price of laptop {i} : "))
# Out:
# enter the price of laptop 1 : 3
# enter the price of laptop 2 : 4
# enter the price of laptop 3 : 5
# enter the price of laptop 4 : 6
# enter the price of laptop 5 : 7

# %%
n=[2,3,4,5,6,7,8,75,67,87]
for i in n[2:-1]:
  print(i)
# Out:
# 4
# 5
# 6
# 7
# 8
# 75
# 67

# %%
n=5
while n>0:
  print(n)
  n-=1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
n=1
while n<5:
  print(n)
  n+=1
# Out:
# 1
# 2
# 3
# 4

# %%
n=int(input())
factorial=1
for i in range(1,n+1):
  factorial=factorial * i
  print(factorial)
# Out:
# 5
# 1
# 2
# 6
# 24
# 120

# %%
def factorial(n):
  fact=1
  for i in range(1,n+1):
    fact=fact*i
    print(fact)
  print("done")

# %%
f=factorial(7)
print(f)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# done
# None

# %%
print(factorial(9))
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# done
# None
